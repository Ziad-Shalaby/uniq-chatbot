# %% [markdown]
# # 🎓 UniQ AI Chatbot — Google Colab
#
# **اللائحة الداخلية · كلية الحاسبات وعلوم البيانات · جامعة الإسكندرية**
#
# ### تعليمات:
# 1. غيّر Runtime إلى **T4 GPU**: Runtime → Change runtime type → T4 GPU
# 2. شغّل الـ Cells بالترتيب
# 3. في Cell الأخير ستظهر رابط عام — افتحه للتحدث مع البوت

# %%
# Cell 1: Check GPU
import torch
print(f'GPU: {torch.cuda.get_device_name(0) if torch.cuda.is_available() else "CPU only"}')
if torch.cuda.is_available():
    print(f'Memory: {torch.cuda.get_device_properties(0).total_memory / 1e9:.1f} GB')

# %%
# Cell 2: Install dependencies
# !pip install -q streamlit transformers accelerate bitsandbytes \
    sentence-transformers chromadb pdfplumber pyngrok
print('Done')

# %%
# Cell 3: Upload project (choose ONE option)

# OPTION A: Upload zip
from google.colab import files
print('Upload uniq-streamlit.zip:')
uploaded = files.upload()
# !unzip -q uniq-streamlit.zip
# %cd uniq-streamlit

# OPTION B: Clone from GitHub (uncomment if you pushed to GitHub)
# !git clone https://github.com/YOUR_USERNAME/uniq-streamlit.git
# %cd uniq-streamlit

# %%
# Cell 4: Run Streamlit + expose via ngrok
import subprocess, time
from pyngrok import ngrok

# Paste your free ngrok token from https://ngrok.com
NGROK_TOKEN = 'YOUR_NGROK_TOKEN_HERE'
ngrok.set_auth_token(NGROK_TOKEN)

# Start Streamlit in background
proc = subprocess.Popen(
    ['streamlit', 'run', 'app.py',
     '--server.port', '8501',
     '--server.headless', 'true',
     '--server.enableCORS', 'false'],
    stdout=subprocess.PIPE,
    stderr=subprocess.PIPE
)

time.sleep(4)  # wait for server to start

# Open public tunnel
url = ngrok.connect(8501)
print('=' * 60)
print('Open this URL in your browser:')
print(f'   {url}')
print('=' * 60)
print('Keep this cell running while you use the app.')
